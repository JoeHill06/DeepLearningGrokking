# %% [markdown]
# # MNIST Convolutional Neural Network (Keras)
#
#   The MNIST training images are all perfectly centred, upright, and similarly sized. This causes the network to overfit to these specific conditions — it learns to recognise a "7" that sits in the middle of the
#   frame at a particular scale, rather than learning what a "7" actually looks like regardless of position, size, or slight rotation. In the real world, handwritten digits won't be perfectly framed, so a model
#   trained only on pristine examples is more brittle than its 99% test accuracy suggests.
#
#   Data augmentation fixes this by applying small random transformations (shifts, rotations, zooms) to each training image on the fly, so the network never sees the exact same image twice. This artificially
#   increases the diversity of the training set without collecting new data, and forces the network to learn features that are invariant to position, angle, and scale — which is what we actually want from a digit
#   classifier.
#
#
# **Architecture:**
# `56×56×1 input → Augmentation → Conv(64, 3×3) → MaxPool(2×2) → Conv(64, 3×3) → MaxPool(2×2) → Flatten → Dense(128, tanh) → Dropout(0.3) → Dense(128, tanh) → Dropout(0.3) → Dense(10, softmax)`
#
# **Techniques:** TensorFlow/Keras high-level API · Convolutional + max-pooling layers · ReLU + tanh + softmax activations · Dropout regularisation · Sparse categorical cross-entropy loss · Adam optimiser · `validation_split` + `EarlyStopping` to prevent overfitting
#
# **Classes:** Digits 0–9
#
#   **Augmentation settings:**
#   | Setting | Value | Effect |
#   |---------|-------|--------|
#   | `image resize` | `(56,56)` | scaled up |
#   | `aug_rotation` | `0.06` | ±~22 degrees |
#   | `aug_translation` | `(0.3, 0.3)` | ±30% shift |
#   | `aug_zoom` | `(0.0, 0.7)` | 0% to 70% smaller |
#   | `aug_fill_mode` | `"constant"` | Fill empty space with black |
#
#   **Result: ~98.7% test accuracy**
#   | Metric | Accuracy | Loss |
#   |--------|----------|------|
#   | Final training | 97.7% | 0.078 |
#   | Final validation | 98.6% | 0.047 |
#   | Test | 98.7% | 0.042 |
#   | Train/test gap | -1.0% | |

# %% [markdown]
# ## Installing Dependencies

# %%
# %pip install tensorflow -q
# Out:
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# ── Imports ───────────────────────────────────────────────────────────────
# MNIST dataset loader (ships with Keras)
from keras.datasets import mnist

# TensorFlow / Keras — the deep-learning framework
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Numerical + plotting helpers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Our Data

# %%
# getting our images
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# getting our training dimensions and counts
training_image_count, training_image_height, training_image_width = x_train.shape[0], x_train.shape[1], x_train.shape[2]

# getting our test dimensions and counts
test_image_count, test_image_height, test_image_width = x_test.shape[0], x_test.shape[1], x_test.shape[2]

# %% [markdown]
# ## Visualising Augmented Digits

# %%
def show_augmented(n=20):
    """Show n random training images alongside their augmented versions."""
    # Build a mini model that ONLY contains the augmentation layers.
    # Calling it in training mode applies the random transforms.
    aug = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(aug_rotation, fill_mode=aug_fill_mode),
        tf.keras.layers.RandomTranslation(*aug_translation, fill_mode=aug_fill_mode),
        tf.keras.layers.RandomZoom(aug_zoom, fill_mode=aug_fill_mode),
    ])

    indices = np.random.randint(0, len(training_images), n)

    cols = 5
    rows = n // cols
    fig, axes = plt.subplots(rows, cols * 2, figsize=(cols * 4, rows * 2.5))

    for i, idx in enumerate(indices):
        row = i // cols
        col = i % cols

        original = training_images[idx]      # (28, 28, 1), already normalised
        augmented = aug(tf.expand_dims(original, 0), training=True)  # (1, 28, 28, 1)
        augmented = augmented[0]             # back to (28, 28, 1)

        # left column: original
        ax_orig = axes[row, col * 2]
        ax_orig.imshow(original[:, :, 0], cmap='gray')
        ax_orig.set_title(f"Original [{y_train[idx]}]", fontsize=7)
        ax_orig.axis('off')

        # right column: augmented
        ax_aug = axes[row, col * 2 + 1]
        ax_aug.imshow(augmented[:, :, 0].numpy(), cmap='gray')
        ax_aug.set_title(f"Augmented [{y_train[idx]}]", fontsize=7)
        ax_aug.axis('off')

    plt.suptitle("Original vs Augmented training images", fontsize=12)
    plt.tight_layout()
    plt.show()

show_augmented()

# %% [markdown]
# ## Building Our Model

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────
input_size  = (training_image_height, training_image_width)  # (28, 28)
hidden_size = 128   # neurons in each fully-connected hidden layer
output_size = 10    # one output per digit class (0–9)
epochs      = 60    # max epochs

# ── Augmentation settings ────────────────────────────────────────────────
aug_rotation    = 0.06          # ±~22 degrees
aug_translation = (0.3, 0.3)   # ±30% shift
aug_zoom        = (0.0, 0.7)   # 0% to 70% smaller
aug_fill_mode   = "constant"   # fill empty space with black

# %%
# Training settings 
num_train = 60000
num_test = 10000
batch_size = 100

# EarlyStopping callback settings
callbacks = [EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)]

# Peparing Data
training_images = (x_train[0:num_train] / 255.0).reshape(num_train, training_image_height, training_image_width, 1)
training_labels = y_train[0:num_train]
training_images = tf.image.resize(training_images, [56, 56]) #upscale images to be bigger

test_images = (x_test[0:num_test] / 255.0).reshape(num_test, test_image_height, test_image_width, 1)
test_labels = y_test[0:num_test]
test_images = tf.image.resize(test_images, [56, 56])

# %%
# Building The Model
model = tf.keras.models.Sequential([
    # ── Data augmentation ──
    tf.keras.layers.RandomRotation(aug_rotation, fill_mode=aug_fill_mode),
    tf.keras.layers.RandomTranslation(*aug_translation, fill_mode=aug_fill_mode),
    tf.keras.layers.RandomZoom(aug_zoom, fill_mode=aug_fill_mode),

    # ── Convolutional feature extractor ──
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu',input_shape=(56, 56, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # ── Deep Neural Network ──
    # Layer_0
    tf.keras.layers.Flatten(),

    # Layer_1
    tf.keras.layers.Dense(hidden_size, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.15),

    # Layer_2
    tf.keras.layers.Dense(hidden_size, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.15),
    
    # Output layer:
    tf.keras.layers.Dense(output_size, activation=tf.nn.softmax),
])

# ── Compile ───────────────────────────────────────────────────────────────
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# ── Train ─────────────────────────────────────────────────────────────────
print("Training…\n")
history = model.fit(training_images, 
                    training_labels,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.1,
                    callbacks=callbacks,
                    verbose=2)

# ── Evaluate on the held-out test set ─────────────────────────────────────
print("\nEvaluating on test set…")
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=0)

# ── Final summary ─────────────────────────────────────────────────────────
final_train_accuracy = history.history["accuracy"][-1]
final_train_loss     = history.history["loss"][-1]
final_val_accuracy   = history.history["val_accuracy"][-1]
final_val_loss       = history.history["val_loss"][-1]
epochs_run           = len(history.history["loss"])

print("\n── Results ───────────────────────────────────────────────")
print(f"Epochs run              : {epochs_run} (of {epochs} requested)")
print(f"Final training accuracy : {final_train_accuracy * 100:.1f}%  (loss {final_train_loss:.3f})")
print(f"Final validation acc.   : {final_val_accuracy   * 100:.1f}%  (loss {final_val_loss:.3f})")
print(f"Test accuracy           : {test_accuracy        * 100:.1f}%  (loss {test_loss:.3f})")
print(f"Train/test gap          : {(final_train_accuracy - test_accuracy) * 100:+.1f}%")
# Out:
# Training…
#
# Epoch 1/60
# 540/540 - 23s - 43ms/step - accuracy: 0.6435 - loss: 1.0356 - val_accuracy: 0.9208 - val_loss: 0.2559
# Epoch 2/60
# 540/540 - 23s - 42ms/step - accuracy: 0.8523 - loss: 0.4608 - val_accuracy: 0.9517 - val_loss: 0.1492
# Epoch 3/60
# 540/540 - 22s - 42ms/step - accuracy: 0.8938 - loss: 0.3363 - val_accuracy: 0.9647 - val_loss: 0.1187
# Epoch 4/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9116 - loss: 0.2773 - val_accuracy: 0.9745 - val_loss: 0.0921
# Epoch 5/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9245 - loss: 0.2447 - val_accuracy: 0.9677 - val_loss: 0.1040
# Epoch 6/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9346 - loss: 0.2115 - val_accuracy: 0.9795 - val_loss: 0.0726
# Epoch 7/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9404 - loss: 0.1930 - val_accuracy: 0.9697 - val_loss: 0.0954
# Epoch 8/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9437 - loss: 0.1836 - val_accuracy: 0.9743 - val_loss: 0.0885
# Epoch 9/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9489 - loss: 0.1669 - val_accuracy: 0.9755 - val_loss: 0.0836
# Epoch 10/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9518 - loss: 0.1581 - val_accuracy: 0.9803 - val_loss: 0.0645
# Epoch 11/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9522 - loss: 0.1531 - val_accuracy: 0.9800 - val_loss: 0.0636
# Epoch 12/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9554 - loss: 0.1450 - val_accuracy: 0.9808 - val_loss: 0.0636
# Epoch 13/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9558 - loss: 0.1427 - val_accuracy: 0.9797 - val_loss: 0.0674
# Epoch 14/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9583 - loss: 0.1331 - val_accuracy: 0.9773 - val_loss: 0.0788
# Epoch 15/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9593 - loss: 0.1314 - val_accuracy: 0.9850 - val_loss: 0.0506
# Epoch 16/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9609 - loss: 0.1274 - val_accuracy: 0.9867 - val_loss: 0.0462
# Epoch 17/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9618 - loss: 0.1226 - val_accuracy: 0.9838 - val_loss: 0.0553
# Epoch 18/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9622 - loss: 0.1235 - val_accuracy: 0.9843 - val_loss: 0.0539
# Epoch 19/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9638 - loss: 0.1175 - val_accuracy: 0.9802 - val_loss: 0.0685
# Epoch 20/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9656 - loss: 0.1117 - val_accuracy: 0.9820 - val_loss: 0.0578
# Epoch 21/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9654 - loss: 0.1115 - val_accuracy: 0.9872 - val_loss: 0.0474
# Epoch 22/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9651 - loss: 0.1135 - val_accuracy: 0.9832 - val_loss: 0.0526
# Epoch 23/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9666 - loss: 0.1100 - val_accuracy: 0.9843 - val_loss: 0.0525
# Epoch 24/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9667 - loss: 0.1068 - val_accuracy: 0.9848 - val_loss: 0.0480
# Epoch 25/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9683 - loss: 0.1027 - val_accuracy: 0.9858 - val_loss: 0.0459
# Epoch 26/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9685 - loss: 0.1022 - val_accuracy: 0.9845 - val_loss: 0.0487
# Epoch 27/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9685 - loss: 0.1054 - val_accuracy: 0.9868 - val_loss: 0.0448
# Epoch 28/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9687 - loss: 0.1007 - val_accuracy: 0.9867 - val_loss: 0.0426
# Epoch 29/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9704 - loss: 0.0989 - val_accuracy: 0.9875 - val_loss: 0.0411
# Epoch 30/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9700 - loss: 0.1002 - val_accuracy: 0.9858 - val_loss: 0.0466
# Epoch 31/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9711 - loss: 0.0948 - val_accuracy: 0.9830 - val_loss: 0.0540
# Epoch 32/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9713 - loss: 0.0954 - val_accuracy: 0.9895 - val_loss: 0.0396
# Epoch 33/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9711 - loss: 0.0951 - val_accuracy: 0.9853 - val_loss: 0.0513
# Epoch 34/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9709 - loss: 0.0942 - val_accuracy: 0.9878 - val_loss: 0.0401
# Epoch 35/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9721 - loss: 0.0903 - val_accuracy: 0.9877 - val_loss: 0.0444
# Epoch 36/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9714 - loss: 0.0936 - val_accuracy: 0.9860 - val_loss: 0.0496
# Epoch 37/60
# 540/540 - 22s - 41ms/step - accuracy: 0.9719 - loss: 0.0908 - val_accuracy: 0.9887 - val_loss: 0.0413
# Epoch 38/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9734 - loss: 0.0865 - val_accuracy: 0.9860 - val_loss: 0.0505
# Epoch 39/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9727 - loss: 0.0891 - val_accuracy: 0.9865 - val_loss: 0.0446
# Epoch 40/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9732 - loss: 0.0877 - val_accuracy: 0.9870 - val_loss: 0.0437
# Epoch 41/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9745 - loss: 0.0838 - val_accuracy: 0.9825 - val_loss: 0.0595
# Epoch 42/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9746 - loss: 0.0835 - val_accuracy: 0.9902 - val_loss: 0.0362
# Epoch 43/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9741 - loss: 0.0854 - val_accuracy: 0.9832 - val_loss: 0.0578
# Epoch 44/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9744 - loss: 0.0841 - val_accuracy: 0.9872 - val_loss: 0.0484
# Epoch 45/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9742 - loss: 0.0824 - val_accuracy: 0.9870 - val_loss: 0.0523
# Epoch 46/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9753 - loss: 0.0818 - val_accuracy: 0.9815 - val_loss: 0.0620
# Epoch 47/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9753 - loss: 0.0834 - val_accuracy: 0.9865 - val_loss: 0.0519
# Epoch 48/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9750 - loss: 0.0824 - val_accuracy: 0.9888 - val_loss: 0.0403
# Epoch 49/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9757 - loss: 0.0811 - val_accuracy: 0.9858 - val_loss: 0.0491
# Epoch 50/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9757 - loss: 0.0779 - val_accuracy: 0.9847 - val_loss: 0.0555
# Epoch 51/60
# 540/540 - 22s - 42ms/step - accuracy: 0.9764 - loss: 0.0760 - val_accuracy: 0.9880 - val_loss: 0.0445
# Epoch 52/60
# 540/540 - 23s - 42ms/step - accuracy: 0.9765 - loss: 0.0783 - val_accuracy: 0.9857 - val_loss: 0.0465
#
# Evaluating on test set…
#
# ── Results ───────────────────────────────────────────────
# Epochs run              : 52 (of 60 requested)
# Final training accuracy : 97.7%  (loss 0.078)
# Final validation acc.   : 98.6%  (loss 0.047)
# Test accuracy           : 98.7%  (loss 0.042)
# Train/test gap          : -1.0%

# %% [markdown]
# ## Saving Our Model

# %%
# saving the model
model.save("mnist_cnn.keras")
print("Saved → mnist_cnn.keras")
# Out:
# Saved → mnist_cnn.keras

# %% [markdown]
# ## Testing Random Predictions

# %%
# ── Test 20 random images: original vs augmented ─────────────────────────                                                                                                                                         
def test_20_digits(n=20):                                                                                                                                                                                           
    aug = tf.keras.Sequential([                                                                                                                                                                                     
        tf.keras.layers.RandomRotation(aug_rotation, fill_mode=aug_fill_mode),                                                                                                                                      
        tf.keras.layers.RandomTranslation(*aug_translation, fill_mode=aug_fill_mode),                                                                                                                               
        tf.keras.layers.RandomZoom(aug_zoom, fill_mode=aug_fill_mode),
    ])                                                                                                                                                                                                              
                                                        
    indices = np.random.randint(0, len(test_images), n)                                                                                                                                                             

    cols = 5                                                                                                                                                                                                        
    rows = n // cols                                      

    fig, axes = plt.subplots(rows, cols * 2, figsize=(cols * 4, rows * 2.5))                                                                                                                                        

    for i, idx in enumerate(indices):                                                                                                                                                                               
        row = i // cols                                   
        col = i % cols

        image = test_images[idx]
        image = tf.image.resize(image, [56, 56])
        true_label = test_labels[idx]
                                                                                                                                                                                                                    
        # augment the image
        augmented = aug(tf.expand_dims(image, 0), training=True)[0]                                                                                                                                                 
                                                        
        # predict on original
        pred_orig = model.predict(image.numpy().reshape(1, 56, 56, 1), verbose=0)
        guess_orig = np.argmax(pred_orig)                                                                                                                                                                           

        # predict on augmented                                                                                                                                                                                      
        pred_aug = model.predict(augmented.numpy().reshape(1, 56, 56, 1), verbose=0)
        guess_aug = np.argmax(pred_aug)                                                                                                                                                                             

        # left column: original                                                                                                                                                                                     
        ax_orig = axes[row, col * 2]                      
        ax_orig.imshow(image[:, :, 0], cmap='gray')
        colour = 'green' if guess_orig == true_label else 'red'
        ax_orig.set_title(f"Label: {true_label}  Guess: {guess_orig}", color=colour, fontsize=7)                                                                                                                    
        ax_orig.axis('off')
                                                                                                                                                                                                                    
        # right column: augmented                         
        ax_aug = axes[row, col * 2 + 1]                                                                                                                                                                             
        ax_aug.imshow(augmented[:, :, 0].numpy(), cmap='gray')
        colour = 'green' if guess_aug == true_label else 'red'
        ax_aug.set_title(f"Label: {true_label}  Guess: {guess_aug}", color=colour, fontsize=7)                                                                                                                      
        ax_aug.axis('off')
                                                                                                                                                                                                                    
    plt.suptitle("Original vs Augmented predictions", fontsize=12)                                                                                                                                                  
    plt.tight_layout()
    plt.show()                                                                                                                                                                                                      
                                                        
test_20_digits()
