# %% [markdown]
# # MNIST Deep Neural Network
#
# Handwritten digit classifier built from scratch in NumPy — no high-level ML frameworks.
#
# **Architecture:** `784 inputs → tanh hidden layer (100 neurons) → dropout → softmax → 10 classes`
#
# **Techniques:** Mini-batch gradient descent · Dropout regularisation · Tanh + Softmax activations · One-hot encoding · MSE loss
#
# **Results:** 97.8% test accuracy on 10,000 unseen images after 200 training iterations using mini-batch gradient descent (batch size 100, alpha 0.06, 75% dropout keep rate). Train/test gap of only ~0.2%, indicating the network generalises well rather than memorising the training data.

# %% [markdown]
# First Step: Getting the data:
# For this we are going to use keras the api for tensor flow to get our dataset.

# %%
# import dataset
from keras.datasets import mnist

# import numpy and matplotlib 
import numpy as np
import matplotlib.pyplot as plt

# for cleaner outputs
import sys

# %% [markdown]
# ---
# ## Loading the Data
#
# `mnist.load_data()` returns two tuples — one for training, one for testing:
#
# - **`x_train`** — a 3D NumPy array of shape `(60000, 28, 28)`: 60,000 images, each a 28×28 grid of pixel values (0–255)
# - **`y_train`** — a 1D array of shape `(60000,)`: the correct digit label (0–9) for each training image
# - **`x_test`** / **`y_test`** — same structure but 10,000 images, kept separate to evaluate the trained network
#
# So `x_train[0]` is the first image (a 28×28 array of numbers) and `y_train[0]` is the digit it shows.
#
# x_train = [
#       [[...28 pixels...], [...28 pixels...], ... 28 rows],  ← image 0
#       [[...28 pixels...], [...28 pixels...], ... 28 rows],  ← image 1
#       ...
#       [[...28 pixels...], [...28 pixels...], ... 28 rows],  ← image 59,999
#   ]
#
#   60,000 "rows", each one being a complete image represented as a 28×28 array.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

training_image_count, training_image_height, training_image_width = x_train.shape[0], x_train.shape[1], x_train.shape[2]
training_label_count, training_label_dtype = y_train.shape[0], y_train.dtype
print(f"Training Data:")
print(f"Training Images: {training_image_count}")
print(f"Each image is {training_image_height} x {training_image_width} pixels; totaling {training_image_height * training_image_width} pixels")
print(f"Training Labels: {training_label_count}")
print(f"Each label is a single integer (0–9), dtype: {training_label_dtype}")

test_image_count, test_image_height, test_image_width = x_test.shape[0], x_test.shape[1], x_test.shape[2]
test_label_count, test_label_dtype = y_test.shape[0], y_test.dtype
print(f"\nTest Data:")
print(f"Test Images: {test_image_count}")
print(f"Each image is {test_image_height} x {test_image_width} pixels; totaling {test_image_height * test_image_width} pixels")
print(f"Test Labels: {test_label_count}")
print(f"Each label is a single integer (0–9), dtype: {test_label_dtype}")
# Out:
# Training Data:
# Training Images: 60000
# Each image is 28 x 28 pixels; totaling 784 pixels
# Training Labels: 60000
# Each label is a single integer (0–9), dtype: uint8
#
# Test Data:
# Test Images: 10000
# Each image is 28 x 28 pixels; totaling 784 pixels
# Test Labels: 10000
# Each label is a single integer (0–9), dtype: uint8

# %% [markdown]
# ---
# ## Helper Functions

# %%
# ── 1. Visualise a single image and its label ─────────────────────────────
def visualize_image_and_label(index, train=True):

    # pick the right dataset based on the train flag
    if train:
        image = x_train[index]   # shape: (28, 28)
        label = y_train[index]   # single integer 0-9
        split = "Train"
    else:
        image = x_test[index]
        label = y_test[index]
        split = "Test"

    plt.figure(figsize=(3, 3))
    plt.imshow(image, cmap='gray')
    plt.title(f"{split} Image {index} — Label: {label}")
    plt.axis('off')
    plt.show()


# ── 2. Visualise a grid of random images ──────────────────────────────────
def visualize_grid(n=10, train=True):
    images = x_train if train else x_test
    labels = y_train if train else y_test

    # pick n random indices from the dataset
    indices = np.random.randint(0, len(images), n)

    # create a row of n subplots side by side
    fig, axes = plt.subplots(1, n, figsize=(n * 1.5, 2))

    for ax, idx in zip(axes, indices):
        ax.imshow(images[idx], cmap='gray')
        ax.set_title(str(labels[idx]))  # show the digit label above each image
        ax.axis('off')

    plt.suptitle("Random sample from dataset", y=1.05)
    plt.tight_layout()
    plt.show()


# ── 3. Visualise learned weights as 28×28 images ──────────────────────────
def visualize_weights(weights_0_1, n=16):
    # weights_0_1 is (784, hidden_size) — each COLUMN is one neuron's weights
    # we take the first n neurons and reshape each from 784 → 28×28

    cols = 8
    rows = n // cols  # how many rows we need in the grid

    fig, axes = plt.subplots(rows, cols, figsize=(cols * 1.5, rows * 1.5))

    for i, ax in enumerate(axes.flat):
        # reshape the 784 weights for neuron i into a 28×28 image
        weight_image = weights_0_1[:, i].reshape(28, 28)
        ax.imshow(weight_image, cmap='bwr')  # bwr = blue-white-red: neg=blue, pos=red
        ax.axis('off')

    plt.suptitle("Learned weight patterns (one per hidden neuron)", y=1.02)
    plt.tight_layout()
    plt.show()


# ── 4. Visualise a dropout mask ───────────────────────────────────────────
def visualize_dropout_mask(mask):
    # mask is (input_size, hidden_size) — 1 = neuron active, 0 = neuron dropped
    # we display it as a black and white image
    # white pixels = active connections, black pixels = dropped connections

    plt.figure(figsize=(8, 3))
    plt.imshow(mask.T, cmap='gray', aspect='auto')  # transpose so neurons are rows
    plt.title("Dropout mask — white=active, black=dropped")
    plt.xlabel("Input pixels (784)")
    plt.ylabel("Hidden neurons (100)")
    plt.colorbar()
    plt.show()


# ── 5. Plot an activation function curve ──────────────────────────────────
def plot_activation(fn, name):
    # generate 200 evenly spaced values between -6 and 6
    x = np.linspace(-6, 6, 200)
    y = fn(x)

    plt.figure(figsize=(6, 3))
    plt.plot(x, y, label=name)
    plt.axhline(0, color='gray', linewidth=0.8, linestyle='--')  # horizontal zero line
    plt.axvline(0, color='gray', linewidth=0.8, linestyle='--')  # vertical zero line
    plt.title(f"Activation function: {name}")
    plt.xlabel("Input value")
    plt.ylabel("Output value")
    plt.legend()
    plt.tight_layout()
    plt.show()


# ── 6. Visualise a prediction after training ──────────────────────────────
def visualize_prediction(index, train=False):
    # pick image and run a forward pass through the trained network
    images = x_train if train else x_test
    labels = y_train if train else y_test

    image = images[index]
    true_label = labels[index]

    # flatten the 28×28 image to a (1, 784) row and normalise pixels to 0–1
    layer_0 = image.flatten() / 255.0
    layer_0 = layer_0.reshape(1, -1)

    # forward pass (no dropout at inference time)
    layer_1 = tanh(np.dot(layer_0, weights_0_1))
    layer_2 = softmax(np.dot(layer_1, weights_1_2))  # shape: (1, 10) — one prob per digit

    probs = layer_2[0]           # pull out the 10 probabilities
    predicted = np.argmax(probs) # digit with highest probability is the prediction

    # plot the image on the left and a bar chart of probabilities on the right
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

    ax1.imshow(image, cmap='gray')
    ax1.set_title(f"True label: {true_label}  |  Predicted: {predicted}")
    ax1.axis('off')

    # bar chart — green if correct digit, red if wrong
    colours = ['green' if i == true_label else 'steelblue' for i in range(10)]
    ax2.bar(range(10), probs, color=colours)
    ax2.set_xticks(range(10))
    ax2.set_xlabel("Digit")
    ax2.set_ylabel("Probability")
    ax2.set_title("Network output probabilities")

    plt.tight_layout()
    plt.show()


# ── 7. Test 20 random images and show label vs guess ──────────────────────
def test_20_digit(w0, w1, n=20):
    # pick n random indices from the test set
    indices = np.random.randint(0, len(x_test), n)

    cols = 5
    rows = n // cols  # e.g. 20 images → 4 rows of 5

    fig, axes = plt.subplots(rows, cols, figsize=(cols * 2, rows * 2.5))

    for ax, idx in zip(axes.flat, indices):
        image = x_test[idx]  # original 28×28 image for display
        true_label = y_test[idx]

        # flatten and normalise for the forward pass
        layer_0 = image.flatten().reshape(1, -1) / 255.0
        layer_1 = tanh(np.dot(layer_0, w0))
        layer_2 = softmax(np.dot(layer_1, w1))
        guess = np.argmax(layer_2)

        # show the image
        ax.imshow(image, cmap='gray')

        # green title if correct, red if wrong
        colour = 'green' if guess == true_label else 'red'
        ax.set_title(f"Label: {true_label}  Guess: {guess}", color=colour, fontsize=8)
        ax.axis('off')

    plt.suptitle("Network predictions on random test images", fontsize=12)
    plt.tight_layout()
    plt.show()


# ── 8. Plot training and test accuracy over iterations ────────────────────
def plot_accuracy(train_accs, test_accs):
    # train_accs and test_accs are lists with one value per iteration
    # e.g. [91.2, 94.6, 95.6, ...] — append to these inside the training loop

    iterations = range(1, len(train_accs) + 1)

    plt.figure(figsize=(8, 4))
    plt.plot(iterations, train_accs, label='Train Accuracy', marker='o')
    plt.plot(iterations, test_accs,  label='Test Accuracy',  marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("Accuracy (%)")
    plt.title("Training vs Test Accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


def save_weights(weights_0_1, weights_1_2, filename="weights.npz"):
    np.savez(filename, weights_0_1=weights_0_1, weights_1_2=weights_1_2)
    print(f"Weights saved to {filename}")

def load_weights(filename="weights.npz"):
    data = np.load(filename)
    return data["weights_0_1"], data["weights_1_2"]

# %% [markdown]
# ---
# ## Network Parameters
#
# Before building the network we define a few key values that control its size and how it learns:
#
# - **`alpha`** — the learning rate. Controls how big a step the network takes when updating its weights. Too high and it overshoots; too low and it learns very slowly.
# - **`input_size`** — 784 (28×28). Each image is flattened into a single row of 784 pixel values to feed into the network.
# - **`hidden_size`** — 100. The number of neurons in the hidden layer. More neurons = more capacity to learn patterns, but slower to train.
# - **`output_size`** — 10. One output neuron per digit (0–9). The network picks whichever has the highest value as its prediction.
# - **`iterations`** — how many times the network loops over the entire training set.
# - **`batch_size`** — how many images the network processes between weight updates. With `batch_size = 100` and 60,000 training images, each iteration does 600 weight updates (one per batch) instead of 60,000 (one per image). This is much faster because NumPy can process the whole batch as a single matrix operation, and the averaged gradient over a batch is less noisy than the gradient from a single sample.

# %% [markdown]
# Creating the network parameters

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────
alpha      = 0.06
input_size = training_image_height * training_image_width # 784
hidden_size = 100
output_size = 10
iterations = 200
batch_size = 100

# %% [markdown]
# ---
# ## Activation Functions
#
# **Hidden layer — Tanh**
#
# Tanh squashes any value into the range (−1, 1) and is centred at zero. This is better than ReLU for image data because it produces both positive and negative activations, giving the network a richer signal to learn from. Centring at zero also means gradients stay larger during backpropagation, so the network learns faster.
#
# **Output layer — Softmax**
#
# Softmax is used because we are classifying into exactly one of 10 mutually exclusive categories (digits 0–9). It converts the 10 raw output scores into probabilities that sum to 1 — so the network outputs something like "72% sure this is a 3, 15% sure it's an 8" etc. The digit with the highest probability is taken as the prediction.

# %%
def tanh(x):        return np.tanh(x)
def tanh_deriv(o):  return 1 - o ** 2

def softmax(x):
    e = np.exp(x - np.max(x, axis=1, keepdims=True))
    return e / np.sum(e, axis=1, keepdims=True)

# %% [markdown]
# ## Network Sizes and Weight Shapes
#
# Each image is a 28×28 pixel grid, flattened into a row of **784 numbers** — this is `layer_0`.
#
# The network has two weight matrices:
#
# | Weight matrix | Shape | Why |
# |---|---|---|
# | `weights_0_1` | (784, 100) | Each of the 784 pixels connects to each of the 100 hidden neurons — one weight per connection |
# | `weights_1_2` | (100, 10) | Each of the 100 hidden neurons connects to each of the 10 output neurons (one per digit) |
#
# The shape rule is always `(previous layer size, next layer size)`.
#
# When we compute `layer_0.dot(weights_0_1)` the dimensions are `(1, 784) × (784, 100) = (1, 100)` — the 784s cancel out and we get a row of 100 hidden values. The same pattern repeats for every layer.
#
# Remember: matrices are written as **(rows × columns)**. For two matrices to multiply, the inner dimensions must match — the result takes the outer dimensions.
#
# ---
#
# ## Initialising Weights with Random Numbers
#
# Weights are initialised randomly using `np.random.random`, which returns values between **0.0 and 1.0**. We shift and scale this range so weights start small and centred near zero — large starting weights cause the network to diverge early in training.
#
# ```python
# # Range 0.0 → 1.0  (default, too large for weights)
# np.random.random((784, 100))
#
# # Range -0.1 → 0.1  (scaled and centred at zero)
# np.random.random((784, 100)) * 0.2 - 0.1
#
# # Range -0.01 → 0.01  (narrow range, used for tanh layers)
# np.random.random((784, 100)) * 0.02 - 0.01
# ```
#
# The formula to shift any range is: `random × (max - min) + min`
#
# `np.random.seed(1)` is set before initialising weights so the same random values are generated every run — this makes results reproducible and easier to debug.
#
#
# ### Dropout Mask
#
# A dropout mask is the same shape as the weight matrix between two layers. It randomly switches neurons off during training to prevent the network from relying too heavily on any single neuron — this helps it generalise better.
#
# `np.random.random` gives values between 0.0 and 1.0. Comparing against a threshold with `< 0.5` produces a boolean array (`True`/`False`), which `.astype(int)` converts to `1`s and `0`s:
#
# ```python
# dropout_mask = (np.random.random((input_size, hidden_size)) < 0.5).astype(int)
# ```
#
# Multiplying the hidden layer by this mask zeros out ~50% of neurons each forward pass. The threshold controls the **keep rate** — `< 0.5` keeps ~50% active, `< 0.8` keeps ~80%, etc.
#
# You could also write `weights_0_1.shape` instead of `(input_size, hidden_size)` since the mask always needs to match the weight matrix exactly.

# %%
# set the random seed to initalize weights randomly. 
np.random.seed(1)

weights_0_1 = np.random.random((input_size, hidden_size)) * 0.02 - 0.01 # this gives a random matrix (784 x 100) of values -0.01 and 0.01
weights_1_2 = np.random.random((hidden_size, output_size)) * 0.2 - 0.1 # this gives a random matrix (100 x 10) of values -0.1, 0.1

# %% [markdown]
# ---
# ## Predict, Compare, Learn
#
# Forward propagation is the process of passing an input through the network layer by layer to produce a prediction.
# Compare and Learn is the process of figuring out how much each neuron was wrong by and updating the weights to fix the error by propagating it backwards.
#
# Each layer takes the previous layer's output, multiplies it by a weight matrix, and passes the result through an activation function:
#
# 1. **layer_0** — the raw input (a flattened, normalised image: 784 numbers)
# 2. **layer_1** — `tanh(layer_0 · weights_0_1)` — the hidden layer, 100 neurons
# 3. **layer_2** — `softmax(layer_1 · weights_1_2)` — the output layer, 10 probabilities (one per digit)
#
# The network's prediction is whichever digit has the highest probability in layer_2.
#
# ### Mini-batch gradient descent
#
# Instead of updating the weights after every single image (stochastic gradient descent), we group the training data into **batches** of `batch_size` images and do **one weight update per batch**. The forward and backward passes operate on the whole batch as a single matrix operation:
#
# - `layer_0` is now `(batch_size, 784)` instead of `(1, 784)`
# - `layer_1` is `(batch_size, 100)` and `layer_2` is `(batch_size, 10)`
# - The gradient is **averaged** across the batch (`errors / batch_size`) so the step size doesn't scale with the batch size
#
# This gives three big wins:
#
# 1. **Speed** — NumPy does the matrix maths in parallel, so processing 100 images at once is barely slower than processing one
# 2. **Smoother gradients** — averaging the error across many samples cancels out per-sample noise, giving steadier updates
# 3. **Fewer total updates per epoch** — 600 updates per iteration instead of 60,000, which means we can crank up `alpha` and run more iterations
#
# After training, the test loop is also vectorised: we run all 10,000 test images through as a single matrix operation since dropout is only applied during training.
#
# **Final result: 97.8% test accuracy after 200 iterations** (batch size 100, alpha 0.06, dropout keep rate 75%).

# %%
num_train = 60000
num_test  = 10000

train_images = x_train[0:num_train].reshape(num_train, 28*28) / 255  # flatten and normalise training images
train_labels = y_train[0:num_train]

test_images = x_test[0:num_test].reshape(num_test, 28*28) / 255    # flatten and normalise test images
test_labels = y_test[0:num_test]

train_accs, test_accs = [], []  # track accuracy each iteration for plotting

for iteration in range(iterations):
    error = 0
    correct_count = 0

    # ── loop through the training set one batch at a time ─────────────────
    for batch_start in range(0, len(train_images), batch_size):
        batch_end = batch_start + batch_size

        # grab this batch
        train_batch        = train_images[batch_start:batch_end]   # (batch_size, 784)
        train_batch_labels = train_labels[batch_start:batch_end]   # (batch_size,)

        # one-hot encode the whole batch at once
        one_hot = np.zeros((batch_size, 10))
        one_hot[np.arange(batch_size), train_batch_labels] = 1     # (batch_size, 10)

        # ── forward pass on the entire batch ──────────────────────────────
        layer_0 = train_batch                                       # (batch_size, 784)
        layer_1 = tanh(np.dot(layer_0, weights_0_1))                # (batch_size, 100)

        # dropout — one mask per sample in the batch
        dropout_mask = (np.random.random(layer_1.shape) < 0.75).astype(int)  # keep ~75%
        layer_1 *= dropout_mask

        layer_2 = softmax(np.dot(layer_1, weights_1_2))             # (batch_size, 10)

        # ── error and correctness across the batch ────────────────────────
        errors = layer_2 - one_hot
        error += np.sum(errors ** 2)
        predictions = np.argmax(layer_2, axis=1)                    # (batch_size,)
        correct_count += int(np.sum(predictions == train_batch_labels))

        # ── backpropagation on the entire batch ───────────────────────────
        # divide by batch_size so the gradient is the AVERAGE error,
        # not the sum — otherwise larger batches would take bigger steps
        layer_2_delta  = errors / batch_size
        layer_1_delta  = layer_2_delta.dot(weights_1_2.T)           # (batch_size, 100)
        layer_1_delta *= tanh_deriv(layer_1)
        layer_1_delta *= dropout_mask                               # don't update dropped neurons

        # ── one weight update per batch (not per image) ───────────────────
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)

    # ── test loop — no weight updates, just measure accuracy ──────────────
    # done as one big matrix op since there's no dropout at inference time
    layer_0_test = test_images
    layer_1_test = tanh(np.dot(layer_0_test, weights_0_1))
    layer_2_test = softmax(np.dot(layer_1_test, weights_1_2))

    test_one_hot = np.zeros((len(test_images), 10))
    test_one_hot[np.arange(len(test_images)), test_labels] = 1

    test_error   = float(np.sum((test_one_hot - layer_2_test) ** 2))
    test_correct = int(np.sum(np.argmax(layer_2_test, axis=1) == test_labels))

    train_acc = correct_count / len(train_images) * 100
    test_acc  = test_correct  / len(test_images)  * 100
    train_accs.append(train_acc)
    test_accs.append(test_acc)

    print(f"Iter: {iteration+1:3d} | Train Acc: {train_acc:.1f}% | Test Acc: {test_acc:.1f}% | Train Err: {error:.3f} | Test Err: {test_error:.3f}")
# Out:
# Iter:   1 | Train Acc: 84.3% | Test Acc: 90.2% | Train Err: 17704.189 | Test Err: 1450.550
# Iter:   2 | Train Acc: 90.1% | Test Acc: 91.6% | Train Err: 9137.629 | Test Err: 1247.219
# Iter:   3 | Train Acc: 91.1% | Test Acc: 92.3% | Train Err: 8134.861 | Test Err: 1155.334
# Iter:   4 | Train Acc: 91.8% | Test Acc: 92.8% | Train Err: 7500.359 | Test Err: 1083.710
# Iter:   5 | Train Acc: 92.3% | Test Acc: 93.3% | Train Err: 7002.287 | Test Err: 1012.956
# Iter:   6 | Train Acc: 92.7% | Test Acc: 93.8% | Train Err: 6663.085 | Test Err: 953.207
# Iter:   7 | Train Acc: 93.0% | Test Acc: 94.2% | Train Err: 6332.531 | Test Err: 899.507
# Iter:   8 | Train Acc: 93.5% | Test Acc: 94.5% | Train Err: 6009.170 | Test Err: 850.587
# Iter:   9 | Train Acc: 93.7% | Test Acc: 94.6% | Train Err: 5774.809 | Test Err: 821.507
# Iter:  10 | Train Acc: 93.9% | Test Acc: 94.9% | Train Err: 5593.355 | Test Err: 779.234
# Iter:  11 | Train Acc: 94.1% | Test Acc: 95.0% | Train Err: 5406.012 | Test Err: 745.919
# Iter:  12 | Train Acc: 94.3% | Test Acc: 95.3% | Train Err: 5216.234 | Test Err: 721.126
# Iter:  13 | Train Acc: 94.5% | Test Acc: 95.3% | Train Err: 5002.166 | Test Err: 697.113
# Iter:  14 | Train Acc: 94.7% | Test Acc: 95.5% | Train Err: 4895.078 | Test Err: 680.503
# Iter:  15 | Train Acc: 94.9% | Test Acc: 95.7% | Train Err: 4737.864 | Test Err: 653.770
# Iter:  16 | Train Acc: 95.0% | Test Acc: 95.9% | Train Err: 4626.470 | Test Err: 635.868
# Iter:  17 | Train Acc: 95.1% | Test Acc: 95.9% | Train Err: 4521.236 | Test Err: 619.552
# Iter:  18 | Train Acc: 95.2% | Test Acc: 96.0% | Train Err: 4427.686 | Test Err: 609.226
# Iter:  19 | Train Acc: 95.3% | Test Acc: 96.1% | Train Err: 4282.932 | Test Err: 592.867
# Iter:  20 | Train Acc: 95.4% | Test Acc: 96.2% | Train Err: 4225.643 | Test Err: 581.209
# Iter:  21 | Train Acc: 95.5% | Test Acc: 96.3% | Train Err: 4128.915 | Test Err: 570.815
# Iter:  22 | Train Acc: 95.6% | Test Acc: 96.3% | Train Err: 4087.563 | Test Err: 564.372
# Iter:  23 | Train Acc: 95.6% | Test Acc: 96.3% | Train Err: 4010.534 | Test Err: 555.316
# Iter:  24 | Train Acc: 95.8% | Test Acc: 96.5% | Train Err: 3930.642 | Test Err: 541.638
# Iter:  25 | Train Acc: 95.7% | Test Acc: 96.6% | Train Err: 3872.183 | Test Err: 536.670
# Iter:  26 | Train Acc: 95.8% | Test Acc: 96.5% | Train Err: 3810.964 | Test Err: 530.088
# Iter:  27 | Train Acc: 95.8% | Test Acc: 96.6% | Train Err: 3807.468 | Test Err: 522.635
# Iter:  28 | Train Acc: 95.9% | Test Acc: 96.7% | Train Err: 3730.499 | Test Err: 515.731
# Iter:  29 | Train Acc: 96.0% | Test Acc: 96.7% | Train Err: 3665.521 | Test Err: 504.187
# Iter:  30 | Train Acc: 96.1% | Test Acc: 96.7% | Train Err: 3592.933 | Test Err: 503.997
# Iter:  31 | Train Acc: 96.1% | Test Acc: 96.8% | Train Err: 3570.962 | Test Err: 499.710
# Iter:  32 | Train Acc: 96.1% | Test Acc: 96.7% | Train Err: 3549.474 | Test Err: 492.841
# Iter:  33 | Train Acc: 96.3% | Test Acc: 96.8% | Train Err: 3409.620 | Test Err: 485.740
# Iter:  34 | Train Acc: 96.4% | Test Acc: 96.8% | Train Err: 3371.822 | Test Err: 481.484
# Iter:  35 | Train Acc: 96.2% | Test Acc: 96.9% | Train Err: 3397.186 | Test Err: 476.031
# Iter:  36 | Train Acc: 96.3% | Test Acc: 96.9% | Train Err: 3349.197 | Test Err: 472.854
# Iter:  37 | Train Acc: 96.3% | Test Acc: 96.9% | Train Err: 3322.682 | Test Err: 462.700
# Iter:  38 | Train Acc: 96.5% | Test Acc: 97.0% | Train Err: 3257.126 | Test Err: 463.211
# Iter:  39 | Train Acc: 96.4% | Test Acc: 97.0% | Train Err: 3258.147 | Test Err: 460.779
# Iter:  40 | Train Acc: 96.4% | Test Acc: 97.0% | Train Err: 3233.892 | Test Err: 453.013
# Iter:  41 | Train Acc: 96.5% | Test Acc: 97.0% | Train Err: 3222.247 | Test Err: 457.936
# Iter:  42 | Train Acc: 96.5% | Test Acc: 97.1% | Train Err: 3212.733 | Test Err: 448.447
# Iter:  43 | Train Acc: 96.5% | Test Acc: 97.1% | Train Err: 3118.769 | Test Err: 443.070
# Iter:  44 | Train Acc: 96.5% | Test Acc: 97.1% | Train Err: 3146.286 | Test Err: 446.740
# Iter:  45 | Train Acc: 96.5% | Test Acc: 97.2% | Train Err: 3097.960 | Test Err: 438.381
# Iter:  46 | Train Acc: 96.8% | Test Acc: 97.1% | Train Err: 2977.480 | Test Err: 433.085
# Iter:  47 | Train Acc: 96.6% | Test Acc: 97.2% | Train Err: 3037.163 | Test Err: 433.536
# Iter:  48 | Train Acc: 96.8% | Test Acc: 97.2% | Train Err: 2915.482 | Test Err: 424.427
# Iter:  49 | Train Acc: 96.7% | Test Acc: 97.3% | Train Err: 2995.951 | Test Err: 427.435
# Iter:  50 | Train Acc: 96.7% | Test Acc: 97.3% | Train Err: 2962.880 | Test Err: 422.512
# Iter:  51 | Train Acc: 96.8% | Test Acc: 97.2% | Train Err: 2911.366 | Test Err: 423.005
# Iter:  52 | Train Acc: 96.9% | Test Acc: 97.3% | Train Err: 2858.178 | Test Err: 418.198
# Iter:  53 | Train Acc: 96.8% | Test Acc: 97.3% | Train Err: 2874.315 | Test Err: 416.081
# Iter:  54 | Train Acc: 96.8% | Test Acc: 97.2% | Train Err: 2875.602 | Test Err: 421.462
# Iter:  55 | Train Acc: 96.8% | Test Acc: 97.3% | Train Err: 2903.901 | Test Err: 413.830
# Iter:  56 | Train Acc: 96.8% | Test Acc: 97.3% | Train Err: 2844.895 | Test Err: 410.577
# Iter:  57 | Train Acc: 96.8% | Test Acc: 97.3% | Train Err: 2831.799 | Test Err: 411.864
# Iter:  58 | Train Acc: 97.0% | Test Acc: 97.2% | Train Err: 2748.251 | Test Err: 407.826
# Iter:  59 | Train Acc: 96.9% | Test Acc: 97.3% | Train Err: 2776.391 | Test Err: 407.421
# Iter:  60 | Train Acc: 97.0% | Test Acc: 97.2% | Train Err: 2752.667 | Test Err: 403.363
# Iter:  61 | Train Acc: 97.1% | Test Acc: 97.3% | Train Err: 2700.618 | Test Err: 400.876
# Iter:  62 | Train Acc: 97.0% | Test Acc: 97.4% | Train Err: 2686.399 | Test Err: 398.213
# Iter:  63 | Train Acc: 97.1% | Test Acc: 97.4% | Train Err: 2646.724 | Test Err: 400.499
# Iter:  64 | Train Acc: 97.1% | Test Acc: 97.4% | Train Err: 2631.097 | Test Err: 399.421
# Iter:  65 | Train Acc: 97.1% | Test Acc: 97.5% | Train Err: 2620.077 | Test Err: 392.273
# Iter:  66 | Train Acc: 97.1% | Test Acc: 97.4% | Train Err: 2648.691 | Test Err: 394.928
# Iter:  67 | Train Acc: 97.1% | Test Acc: 97.5% | Train Err: 2588.461 | Test Err: 391.862
# Iter:  68 | Train Acc: 97.1% | Test Acc: 97.5% | Train Err: 2637.072 | Test Err: 391.041
# Iter:  69 | Train Acc: 97.1% | Test Acc: 97.5% | Train Err: 2584.957 | Test Err: 385.184
# Iter:  70 | Train Acc: 97.1% | Test Acc: 97.5% | Train Err: 2596.108 | Test Err: 388.636
# Iter:  71 | Train Acc: 97.2% | Test Acc: 97.5% | Train Err: 2612.840 | Test Err: 386.507
# Iter:  72 | Train Acc: 97.3% | Test Acc: 97.5% | Train Err: 2478.500 | Test Err: 384.622
# Iter:  73 | Train Acc: 97.2% | Test Acc: 97.5% | Train Err: 2507.133 | Test Err: 381.715
# Iter:  74 | Train Acc: 97.2% | Test Acc: 97.5% | Train Err: 2514.231 | Test Err: 382.719
# Iter:  75 | Train Acc: 97.2% | Test Acc: 97.5% | Train Err: 2544.235 | Test Err: 380.812
# Iter:  76 | Train Acc: 97.2% | Test Acc: 97.6% | Train Err: 2486.946 | Test Err: 379.211
# Iter:  77 | Train Acc: 97.2% | Test Acc: 97.6% | Train Err: 2450.785 | Test Err: 377.622
# Iter:  78 | Train Acc: 97.3% | Test Acc: 97.5% | Train Err: 2458.407 | Test Err: 382.306
# Iter:  79 | Train Acc: 97.3% | Test Acc: 97.6% | Train Err: 2414.928 | Test Err: 375.832
# Iter:  80 | Train Acc: 97.3% | Test Acc: 97.6% | Train Err: 2471.335 | Test Err: 373.889
# Iter:  81 | Train Acc: 97.2% | Test Acc: 97.6% | Train Err: 2476.843 | Test Err: 373.309
# Iter:  82 | Train Acc: 97.3% | Test Acc: 97.6% | Train Err: 2395.271 | Test Err: 373.944
# Iter:  83 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2379.603 | Test Err: 371.242
# Iter:  84 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2334.634 | Test Err: 369.968
# Iter:  85 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2339.518 | Test Err: 371.320
# Iter:  86 | Train Acc: 97.3% | Test Acc: 97.7% | Train Err: 2414.722 | Test Err: 367.126
# Iter:  87 | Train Acc: 97.4% | Test Acc: 97.7% | Train Err: 2374.440 | Test Err: 370.380
# Iter:  88 | Train Acc: 97.5% | Test Acc: 97.5% | Train Err: 2308.043 | Test Err: 373.370
# Iter:  89 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2347.849 | Test Err: 373.402
# Iter:  90 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2361.509 | Test Err: 370.143
# Iter:  91 | Train Acc: 97.4% | Test Acc: 97.7% | Train Err: 2323.064 | Test Err: 364.000
# Iter:  92 | Train Acc: 97.4% | Test Acc: 97.6% | Train Err: 2292.030 | Test Err: 365.889
# Iter:  93 | Train Acc: 97.5% | Test Acc: 97.7% | Train Err: 2271.862 | Test Err: 362.386
# Iter:  94 | Train Acc: 97.5% | Test Acc: 97.7% | Train Err: 2245.835 | Test Err: 367.191
# Iter:  95 | Train Acc: 97.5% | Test Acc: 97.7% | Train Err: 2243.083 | Test Err: 362.949
# Iter:  96 | Train Acc: 97.5% | Test Acc: 97.6% | Train Err: 2227.444 | Test Err: 364.742
# Iter:  97 | Train Acc: 97.5% | Test Acc: 97.7% | Train Err: 2267.703 | Test Err: 364.243
# Iter:  98 | Train Acc: 97.5% | Test Acc: 97.7% | Train Err: 2259.521 | Test Err: 364.674
# Iter:  99 | Train Acc: 97.5% | Test Acc: 97.8% | Train Err: 2214.482 | Test Err: 362.176
# Iter: 100 | Train Acc: 97.5% | Test Acc: 97.8% | Train Err: 2281.964 | Test Err: 358.433
# Iter: 101 | Train Acc: 97.5% | Test Acc: 97.6% | Train Err: 2218.402 | Test Err: 362.296
# Iter: 102 | Train Acc: 97.5% | Test Acc: 97.6% | Train Err: 2208.937 | Test Err: 364.921
# Iter: 103 | Train Acc: 97.7% | Test Acc: 97.7% | Train Err: 2139.439 | Test Err: 358.731
# Iter: 104 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2131.975 | Test Err: 362.889
# Iter: 105 | Train Acc: 97.6% | Test Acc: 97.6% | Train Err: 2195.449 | Test Err: 365.425
# Iter: 106 | Train Acc: 97.6% | Test Acc: 97.7% | Train Err: 2162.335 | Test Err: 360.820
# Iter: 107 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2124.391 | Test Err: 356.761
# Iter: 108 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2173.619 | Test Err: 355.576
# Iter: 109 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2135.714 | Test Err: 358.029
# Iter: 110 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2172.562 | Test Err: 356.102
# Iter: 111 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2165.400 | Test Err: 356.213
# Iter: 112 | Train Acc: 97.6% | Test Acc: 97.8% | Train Err: 2155.778 | Test Err: 355.261
# Iter: 113 | Train Acc: 97.5% | Test Acc: 97.8% | Train Err: 2244.637 | Test Err: 358.536
# Iter: 114 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2088.674 | Test Err: 354.407
# Iter: 115 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2107.549 | Test Err: 356.256
# Iter: 116 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2064.300 | Test Err: 357.196
# Iter: 117 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1979.497 | Test Err: 357.809
# Iter: 118 | Train Acc: 97.7% | Test Acc: 97.7% | Train Err: 2071.091 | Test Err: 357.519
# Iter: 119 | Train Acc: 97.8% | Test Acc: 97.9% | Train Err: 2034.186 | Test Err: 355.262
# Iter: 120 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2065.170 | Test Err: 355.565
# Iter: 121 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2041.340 | Test Err: 353.761
# Iter: 122 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2060.781 | Test Err: 350.071
# Iter: 123 | Train Acc: 97.7% | Test Acc: 97.8% | Train Err: 2030.370 | Test Err: 355.565
# Iter: 124 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 2007.064 | Test Err: 354.046
# Iter: 125 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 2008.836 | Test Err: 353.511
# Iter: 126 | Train Acc: 97.8% | Test Acc: 97.7% | Train Err: 1982.671 | Test Err: 356.021
# Iter: 127 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1978.709 | Test Err: 356.654
# Iter: 128 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1935.502 | Test Err: 355.690
# Iter: 129 | Train Acc: 97.8% | Test Acc: 97.7% | Train Err: 1995.486 | Test Err: 353.960
# Iter: 130 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1978.356 | Test Err: 355.570
# Iter: 131 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1958.455 | Test Err: 350.707
# Iter: 132 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1983.343 | Test Err: 345.592
# Iter: 133 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1948.309 | Test Err: 349.291
# Iter: 134 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1981.101 | Test Err: 356.386
# Iter: 135 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1869.890 | Test Err: 349.202
# Iter: 136 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1927.346 | Test Err: 348.911
# Iter: 137 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1957.852 | Test Err: 350.975
# Iter: 138 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1908.245 | Test Err: 351.106
# Iter: 139 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1959.031 | Test Err: 349.834
# Iter: 140 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1931.123 | Test Err: 353.128
# Iter: 141 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1877.331 | Test Err: 347.691
# Iter: 142 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1855.883 | Test Err: 345.794
# Iter: 143 | Train Acc: 97.9% | Test Acc: 97.9% | Train Err: 1918.840 | Test Err: 346.487
# Iter: 144 | Train Acc: 97.9% | Test Acc: 97.9% | Train Err: 1890.359 | Test Err: 344.361
# Iter: 145 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1914.715 | Test Err: 349.377
# Iter: 146 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1907.021 | Test Err: 351.237
# Iter: 147 | Train Acc: 97.8% | Test Acc: 97.8% | Train Err: 1931.924 | Test Err: 345.199
# Iter: 148 | Train Acc: 98.0% | Test Acc: 97.7% | Train Err: 1862.917 | Test Err: 350.576
# Iter: 149 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1846.747 | Test Err: 348.338
# Iter: 150 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1891.609 | Test Err: 346.220
# Iter: 151 | Train Acc: 97.9% | Test Acc: 97.8% | Train Err: 1872.425 | Test Err: 348.993
# Iter: 152 | Train Acc: 98.0% | Test Acc: 97.9% | Train Err: 1782.740 | Test Err: 344.586
# Iter: 153 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1845.705 | Test Err: 350.222
# Iter: 154 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1822.542 | Test Err: 347.445
# Iter: 155 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1806.505 | Test Err: 344.140
# Iter: 156 | Train Acc: 98.0% | Test Acc: 97.9% | Train Err: 1833.848 | Test Err: 344.864
# Iter: 157 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1784.708 | Test Err: 345.307
# Iter: 158 | Train Acc: 97.9% | Test Acc: 97.9% | Train Err: 1881.405 | Test Err: 346.864
# Iter: 159 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1810.024 | Test Err: 348.793
# Iter: 160 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1830.437 | Test Err: 347.241
# Iter: 161 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1805.271 | Test Err: 351.934
# Iter: 162 | Train Acc: 98.0% | Test Acc: 97.9% | Train Err: 1813.324 | Test Err: 346.535
# Iter: 163 | Train Acc: 98.0% | Test Acc: 97.9% | Train Err: 1805.338 | Test Err: 347.120
# Iter: 164 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1815.170 | Test Err: 350.619
# Iter: 165 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1771.914 | Test Err: 349.542
# Iter: 166 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1765.041 | Test Err: 345.917
# Iter: 167 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1800.309 | Test Err: 347.789
# Iter: 168 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1813.807 | Test Err: 348.223
# Iter: 169 | Train Acc: 98.0% | Test Acc: 97.9% | Train Err: 1796.805 | Test Err: 343.415
# Iter: 170 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1743.598 | Test Err: 348.562
# Iter: 171 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1673.892 | Test Err: 345.011
# Iter: 172 | Train Acc: 98.1% | Test Acc: 97.9% | Train Err: 1738.907 | Test Err: 344.784
# Iter: 173 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1733.653 | Test Err: 344.464
# Iter: 174 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1752.244 | Test Err: 348.480
# Iter: 175 | Train Acc: 98.0% | Test Acc: 97.8% | Train Err: 1776.510 | Test Err: 340.386
# Iter: 176 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1714.571 | Test Err: 343.893
# Iter: 177 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1688.993 | Test Err: 352.467
# Iter: 178 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1728.948 | Test Err: 347.024
# Iter: 179 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1675.690 | Test Err: 347.832
# Iter: 180 | Train Acc: 98.0% | Test Acc: 97.7% | Train Err: 1771.464 | Test Err: 348.510
# Iter: 181 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1726.001 | Test Err: 348.105
# Iter: 182 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1698.494 | Test Err: 348.547
# Iter: 183 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1751.016 | Test Err: 350.869
# Iter: 184 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1699.041 | Test Err: 354.270
# Iter: 185 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1704.878 | Test Err: 346.298
# Iter: 186 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1724.232 | Test Err: 348.092
# Iter: 187 | Train Acc: 98.1% | Test Acc: 97.9% | Train Err: 1720.559 | Test Err: 346.276
# Iter: 188 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1625.071 | Test Err: 352.825
# Iter: 189 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1663.779 | Test Err: 343.563
# Iter: 190 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1710.960 | Test Err: 346.432
# Iter: 191 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1691.919 | Test Err: 348.566
# Iter: 192 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1619.815 | Test Err: 348.822
# Iter: 193 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1736.750 | Test Err: 344.372
# Iter: 194 | Train Acc: 98.1% | Test Acc: 97.8% | Train Err: 1681.335 | Test Err: 349.718
# Iter: 195 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1626.682 | Test Err: 350.676
# Iter: 196 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1659.637 | Test Err: 352.236
# Iter: 197 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1646.760 | Test Err: 346.636
# Iter: 198 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1616.018 | Test Err: 351.352
# Iter: 199 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1635.670 | Test Err: 346.815
# Iter: 200 | Train Acc: 98.2% | Test Acc: 97.8% | Train Err: 1657.210 | Test Err: 352.236

# %%
# Plot Accuracy Curve
plot_accuracy(train_accs, test_accs)

# %%
weights_0_1, weights_1_2 = load_weights()
# test on 20 digits
test_20_digit(weights_0_1, weights_1_2)
